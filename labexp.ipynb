# %%
print("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello \n World")
# Out:
# Hello
#  World

# %%
print("'Rohit 's date of birth is 12/05/1999' ")
# Out:
# 'Rohit 's date of birth is 12/05/1999'

# %%
x = "Hello"

print(x)
# Out:
# Hello

# %%
num = 25
print("Integer:", num)

pi = 3.14
print("Float:", pi)


name = "Anusha"
print("String:", name)


is_student = True
print("Boolean:", is_student)


fruits = ["Apple", "Banana", "Mango"]
print("List:", fruits)


coordinates = (10, 20)
print("Tuple:", coordinates)


unique_numbers = {1, 2, 3, 4}
print("Set:", unique_numbers)


student = {"name": "Rohit", "age": 20, "course": "BCA"}
print("Dictionary:", student)
# Out:
# Integer: 25
# Float: 3.14
# String: Anusha
# Boolean: True
# List: ['Apple', 'Banana', 'Mango']
# Tuple: (10, 20)
# Set: {1, 2, 3, 4}
# Dictionary: {'name': 'Rohit', 'age': 20, 'course': 'BCA'}

# %%
a = "Anusha"
b = "Agarwal"
full_name = a + " " + b
print("Full Name:", full_name)
# Out:
# Full Name: Anusha Agarwal

# %%
a = "Anusha"
b = "Agarwal"
c = "(Siya)"
d = a + " " + c + " " + b
print("Full Name:", d)
# Out:
# Full Name: Anusha (Siya) Agarwal

# %%
name = "Anusha Agarwal"
sapid = 590021095
date_of_birth = "30 sep 2007"
address = "UPES\n Bidholi Campus\n Pincode: 248007"
programme ="AI & ML"
semester = 2

print("Name:",name)
print("SAP ID:",sapid)
print("Date of Birth:", date_of_birth)
print("Address:", address)
print("Programme:", programme)
print("Semester:",semester)
# Out:
# Name: Anusha Agarwal
# SAP ID: 590021095
# Date of Birth: 30 sep 2007
# Address: UPES
#  Bidholi Campus
#  Pincode: 248007
# Programme: AI & ML
# Semester: 2
