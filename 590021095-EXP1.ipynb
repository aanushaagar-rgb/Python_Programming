# %% [markdown]
# ## PYTHON PROGRAMMING LAB EXPERIMENT 1 -
#
# ---

# %% [markdown]
# ### 1. Python Installation and Modes

# %% [markdown]
# python can be installed from the official website. Python supports two mode:
#
# * Interactive Mode: Executes code line by line and gives immediate output.
#
# * Script Mode: Executes code written in a file {.py} at once.
#
# ---

# %% [markdown]
# ### 2. Python Programs to print Strings
# a. Hello Everyone !!

# %%
print ("Hello Everyone !!")
# Out:
# Hello Everyone !!

# %% [markdown]
# b. Hello
#
# World

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %% [markdown]
# c. Hello
#
#      World

# %%
print ("Hello \n World")
# Out:
# Hello
#  World

# %% [markdown]
# d. 'Rohit's date of birth is 12\05\1999

# %%
print ("Rohit's date of birth is 12\\05\\1995")
# Out:
# Rohit's date of birth is 12\05\1995

# %% [markdown]
# ---
# ### 3. String Variable (x) and assign value "Hello"

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# ---
# ### 4. Printing Different Datatypes

# %%
a = 10
b = 3.14
c = "Python"
d = True

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 3.14
# Python
# True

# %% [markdown]
# ---
#
# ### 5. Assigning First Name and Last Name

# %%
a = "Anusha"
b = "Agarwal"
print(a + " " + b)
# Out:
# Anusha Agarwal

# %% [markdown]
# ---
#
# ### 6. Name with Nickname

# %%
first_name = "George"
nickname = "woody"
last_name = "Washington"

print(first_name + " (" + nickname + ") " + last_name)
# Out:
# George (woody) Washington

# %% [markdown]
# ---
#
# ### 7. Student Information Program

# %%
name = "NIKUNJ BANSAL"
sap_id = "500069944"
dob = "13 Oct 1999"
address = "UPES\nBidholi Campus\nPincode: 248007"
programme = "AI & ML"
semester = 2

print("NAME:", name)
print("SAP ID:", sap_id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:\n", address)
print("Programme:", programme)
print("Semester:", semester)
# Out:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS:
#  UPES
# Bidholi Campus
# Pincode: 248007
# Programme: AI & ML
# Semester: 2
